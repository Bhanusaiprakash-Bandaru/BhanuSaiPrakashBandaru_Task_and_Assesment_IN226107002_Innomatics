# %% [markdown]
# ![image.png](attachment:ad3ea253-5084-43f4-9c38-ff6d7d0ee6df.png)

# %%
def recharge(amount):
    if amount >= 50 and amount in [199, 299, 399, 599]:
        return "Recharge Successful"
    else:
        return "Invalid Recharge"

while True:
    amt = int(input("Enter amount: "))
    print(recharge(amt))
    if recharge(amt) == "Recharge Successful":
        break
# Out:
# Enter amount:  50
# Invalid Recharge
# Enter amount:  599
# Recharge Successful

# %% [markdown]
# ![image.png](attachment:1751609f-6803-471d-9b12-03c997254110.png)

# %%
def check_stock(products):
    for item in products:
        if products[item] < 15:
            print(item, "Reorder Alert")
        else:
            print(item, "Stock OK")

products = {"Rice": 10, "Wheat": 20, "Sugar": 12}
check_stock(products)
# Out:
# Rice Reorder Alert
# Wheat Stock OK
# Sugar Reorder Alert

# %% [markdown]
# ![image.png](attachment:76bcbc67-9a75-4731-b1be-433764f48a7e.png)

# %%
def result(marks):
    avg = sum(marks) / len(marks)
    if avg >= 50:
        return "Pass"
    else:
        return "Fail"

print(result([45, 60, 55, 40]))
# Out:
# Pass

# %% [markdown]
# ![image.png](attachment:aa3cc280-a500-47e0-a06b-02df9fc153e1.png)

# %%
def fare(km, peak):
    total = 50 + km * 12
    if peak == "yes":
        total *= 1.25
    return total

while True:
    km = int(input("Enter km: "))
    peak = input("Peak hour (yes/no): ")
    print("Fare:", fare(km, peak))
    if input("Retry? (yes/no): ") == "no":
        break
# Out:
# Enter km:  20
# Peak hour (yes/no):  yes
# Fare: 362.5
# Retry? (yes/no):  no

# %% [markdown]
# ![image.png](attachment:7b68ca97-7953-4436-b82e-1d9589fc1d57.png)

# %%
def attendance_check(att):
    p = att.count("P")
    percent = (p / len(att)) * 100
    if percent >= 75:
        return "Eligible"
    else:
        return "Not Eligible"

print(attendance_check(["P","A","P","P","A","P"]))
# Out:
# Not Eligible

# %% [markdown]
# ![image.png](attachment:76b502ec-f864-4528-ab46-210422efc589.png)

# %%
def check_password(pwd):
    if len(pwd) < 8:
        return "Weak"
    digit = False
    special = False
    for ch in pwd:
        if ch.isdigit():
            digit = True
        if ch in "@#$":
            special = True
    if digit and special:
        return "Strong"
    else:
        return "Weak"
print(check_password("abc@1234"))
# Out:
# Strong
